# %%
print("Hello")
# Out:
# Hello

# %%
print("Rachata")
# Out:
# Rachata

# %%
import pandas as pd
A = pd.Series([10,20,30,40])

# %%
print(A)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
A[0]
# Out:
# 10
